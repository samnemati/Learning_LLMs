# %%
# the text
text = [ 'All that we are is the result of what we have thought',
         'To be or not to be that is the question',
         'Be yourself everyone else is already taken' ]

text
# Out:
# ['All that we are is the result of what we have thought',
#  'To be or not to be that is the question',
#  'Be yourself everyone else is already taken']

# %%
# separate into words by splitting by spaces
import re
re.split('\s',text[0])
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/vc/1rbwbb250_n792l81x9pj28h0000gr/T/ipykernel_51114/1325930493.py:3: SyntaxWarning: invalid escape sequence '\s'
#   re.split('\s',text[0])
# ['All',
#  'that',
#  'we',
#  'are',
#  'is',
#  'the',
#  'result',
#  'of',
#  'what',
#  'we',
#  'have',
#  'thought']

# %%
# can recombine into a string with join
' '.join(re.split('\s',text[0]))
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/vc/1rbwbb250_n792l81x9pj28h0000gr/T/ipykernel_51114/346102004.py:2: SyntaxWarning: invalid escape sequence '\s'
#   ' '.join(re.split('\s',text[0]))
# 'All that we are is the result of what we have thought'

# %%
# also make lowercase
allwords = ' '.join(re.split('\s',text[0])).lower()
allwords
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/vc/1rbwbb250_n792l81x9pj28h0000gr/T/ipykernel_51114/1305219009.py:2: SyntaxWarning: invalid escape sequence '\s'
#   allwords = ' '.join(re.split('\s',text[0])).lower()
# 'all that we are is the result of what we have thought'

# %%
# also make lower-case
allwords = re.split('\s',' '.join(text).lower())
allwords
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/vc/1rbwbb250_n792l81x9pj28h0000gr/T/ipykernel_51114/2651653478.py:2: SyntaxWarning: invalid escape sequence '\s'
#   allwords = re.split('\s',' '.join(text).lower())
# ['all',
#  'that',
#  'we',
#  'are',
#  'is',
#  'the',
#  'result',
#  'of',
#  'what',
#  'we',
#  'have',
#  'thought',
#  'to',
#  'be',
#  'or',
#  'not',
#  'to',
#  'be',
#  'that',
#  'is',
#  'the',
#  'question',
#  'be',
#  'yourself',
#  'everyone',
#  'else',
#  'is',
#  'already',
#  'taken']

# %%
# find the unique words
vocab = sorted(set(allwords))
vocab
# Out:
# ['all',
#  'already',
#  'are',
#  'be',
#  'else',
#  'everyone',
#  'have',
#  'is',
#  'not',
#  'of',
#  'or',
#  'question',
#  'result',
#  'taken',
#  'that',
#  'the',
#  'thought',
#  'to',
#  'we',
#  'what',
#  'yourself']

# %%
print(f'There are {len(allwords)} words in the text, and {len(vocab)} words in the vocabulary')
# Out:
# There are 29 words in the text, and 21 words in the vocabulary

# %% [markdown]
# Create encoder and decoder

# %%
# the encoder is a python dictionary type
word2idx = {}
for i,word in enumerate(vocab):
  word2idx[word] = i
word2idx
# Out:
# {'all': 0,
#  'already': 1,
#  'are': 2,
#  'be': 3,
#  'else': 4,
#  'everyone': 5,
#  'have': 6,
#  'is': 7,
#  'not': 8,
#  'of': 9,
#  'or': 10,
#  'question': 11,
#  'result': 12,
#  'taken': 13,
#  'that': 14,
#  'the': 15,
#  'thought': 16,
#  'to': 17,
#  'we': 18,
#  'what': 19,
#  'yourself': 20}

# %%
# and a decoder
idx2word = {}
for i,word in enumerate(vocab):
  idx2word[i] = word
idx2word
# Out:
# {0: 'all',
#  1: 'already',
#  2: 'are',
#  3: 'be',
#  4: 'else',
#  5: 'everyone',
#  6: 'have',
#  7: 'is',
#  8: 'not',
#  9: 'of',
#  10: 'or',
#  11: 'question',
#  12: 'result',
#  13: 'taken',
#  14: 'that',
#  15: 'the',
#  16: 'thought',
#  17: 'to',
#  18: 'we',
#  19: 'what',
#  20: 'yourself'}

# %%
print(f'The word "to" has index {word2idx["to"]}')
print(f'The index "7" maps to the word "{idx2word[7]}"')
# Out:
# The word "to" has index 17
# The index "7" maps to the word "is"

# %%
# select random words from the dictionary
import numpy as np
randidx = np.random.randint(0,len(vocab),size=5)

# words of wisdom as a list of tokens
[ idx2word[i] for i in randidx ]
# Out:
# ['what', 'all', 'be', 'the', 'the']

# %%
# does it sound more wise as text??
' '.join([ idx2word[i] for i in randidx ])
# Out:
# 'what all be the the'

# %%
# translate the text into numbers
text_as_int = [ word2idx[word] for word in allwords ]
text_as_int
# Out:
# [0,
#  14,
#  18,
#  2,
#  7,
#  15,
#  12,
#  9,
#  19,
#  18,
#  6,
#  16,
#  17,
#  3,
#  10,
#  8,
#  17,
#  3,
#  14,
#  7,
#  15,
#  11,
#  3,
#  20,
#  5,
#  4,
#  7,
#  1,
#  13]

# %%
# and numbers back into text
for tokeni in text_as_int:
  print(f'Token {tokeni:2}: {idx2word[tokeni]}')
# Out:
# Token  0: all
# Token 14: that
# Token 18: we
# Token  2: are
# Token  7: is
# Token 15: the
# Token 12: result
# Token  9: of
# Token 19: what
# Token 18: we
# Token  6: have
# Token 16: thought
# Token 17: to
# Token  3: be
# Token 10: or
# Token  8: not
# Token 17: to
# Token  3: be
# Token 14: that
# Token  7: is
# Token 15: the
# Token 11: question
# Token  3: be
# Token 20: yourself
# Token  5: everyone
# Token  4: else
# Token  7: is
# Token  1: already
# Token 13: taken
